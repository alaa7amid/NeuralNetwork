# %%
#requried libraries
import numpy as np
from numpy.random import rand
import matplotlib.pyplot as plt

# %%
#dataset
x = np.array(([0.9,0.8],[0.6,0.3],[0.9,0.1],[0.9,0.8])) #feature
y = np.array(([0],[1],[1],[0])) #labels(0,1)

# %%
x.shape[1]
# Out:
# 2

# %%
# Activation function
def sigmoid(z):
    return 1/(1+np.exp(-z))

#Multi-layers feedforward neural network (2 hidden layers)
class NeuralNetwork:
    def __init__(self, x, y, nodes_in_layer1 = 4, nodes_in_layer2 = 3, nodes_in_layer3 = 1, l_rate = 1):
        #define x, y
        self.inputs_in_layer0 = x  #layer 0
        self.y = y
        
        self.l_rate = l_rate  #learning rate
        
        #define and set the number of neurons in each layers
        self.nodes_in_layer1 = nodes_in_layer1
        self.nodes_in_layer2 = nodes_in_layer2
        self.nodes_in_layer3 = nodes_in_layer3
        
        #intialize the wieghts (theta) metrices
        self.thetas_layer0 = np.random.rand(self.inputs_in_layer0.shape[1] + 1,self.nodes_in_layer1)  #shape: [2+1, 4]
        self.thetas_layer1 = np.random.rand(self.nodes_in_layer1 + 1,self.nodes_in_layer2)  #shape: [4+1, 3]
        self.thetas_layer2 = np.random.rand(self.nodes_in_layer2+1, nodes_in_layer3)  # shape: [3+1, 1]

    def feedforward(self):      
        #compute all the nodes (a1, a2, a3, a4) in layer1
        n = self.inputs_in_layer0.shape[0]

        self.Z1 = self.thetas_layer0[0] + np.dot(self.inputs_in_layer0, self.thetas_layer0[1:])
        self.layer1 = sigmoid(self.Z1)  #values of a1, a2, a3, a4 in layer 1
        
        #compute all the nodes (a1, a2, a3) in layer2
        self.Z2 = self.thetas_layer1[0] + np.dot(self.layer1, self.thetas_layer1[1:])
        self.layer2 = sigmoid(self.Z2)  #values of a1, a2, a3 in layer 2
        
        #compute all the nodes (a1) in layer3
        self.Z3 = self.thetas_layer2[0] + np.dot(self.layer2, self.thetas_layer2[1:])
        self.layer3 = sigmoid(self.Z3)  #output layer      
        
        return self.layer3
    
    def cost_func(self):
        
        self.n = self.inputs_in_layer0.shape[0] #number of training examples
        self.cost = (1/self.n) * np.sum(-self.y * np.log(self.layer3) - (1 - self.y) * np.log(1 - self.layer3)) #cross entropy
        return self.cost 

    
    def backprop(self):
        
        #dervative of E with respect to theta and bias in layer2
        self.dE_dlayer3 = (1/self.n) * (self.layer3-y)/(self.layer3*(1-self.layer3))
        self.dE_dZ3 = np.multiply(self.dE_dlayer3, (sigmoid(self.Z3)* (1-sigmoid(self.Z3))))
        self.dE_dtheta2 = np.dot(self.layer2.T, self.dE_dZ3)
        self.dE_dbias2 = np.dot(np.ones(self.n), self.dE_dZ3)
        
        #dervative of E with respect to theta and bias in layer1
        self.dE_dlayer2 = np.dot(self.dE_dZ3, self.thetas_layer2[1:].T)
        self.dE_dZ2 = np.multiply(self.dE_dlayer2, sigmoid(self.Z2)* (1-sigmoid(self.Z2)))
        self.dE_dtheta1 = np.dot(self.layer1.T, self.dE_dZ2)
        self.dE_dbias1 = np.dot(np.ones(self.n), self.dE_dZ2)
        
        #dervative of E with respect to theta and bias in layer0
        self.dE_dlayer1 = np.dot(self.dE_dZ2, self.thetas_layer1[1:].T)
        self.dE_dZ1 = np.multiply(self.dE_dlayer1, sigmoid(self.Z1)* (1-sigmoid(self.Z1)))
        self.dE_dtheta0 = np.dot(self.inputs_in_layer0.T, self.dE_dZ1)
        self.dE_dbias0 = np.dot(np.ones(self.n), self.dE_dZ1)
        
        #updating theta using gradient descent in layers 2, 1, and 0
        self.thetas_layer2[1:] = self.thetas_layer2[1:] - self.l_rate * self.dE_dtheta2
        self.thetas_layer1[1:] = self.thetas_layer1[1:] - self.l_rate * self.dE_dtheta1
        self.thetas_layer0[1:] = self.thetas_layer0[1:] - self.l_rate * self.dE_dtheta0
        
        #updating bias using gradient descent in layers 2, 1, and 0
        self.thetas_layer2[0] = self.thetas_layer2[0] - self.l_rate * self.dE_dbias2
        self.thetas_layer1[0] = self.thetas_layer1[0] - self.l_rate * self.dE_dbias1
        self.thetas_layer0[0] = self.thetas_layer0[0] - self.l_rate * self.dE_dbias0
        
        
        return self

# %%
NN = NeuralNetwork(x,y)
epochs=1000
losses=[]
for i in range(epochs):
    predicted_output = NN.feedforward()
    error=NN.cost_func()
    losses.append(error)
    u=NN.backprop()
    print("iteration # ", i+1)
    print ("Actual Output: \n", y)
    print("Predicted Output: \n", predicted_output, "\n")
    print("cost \n", error ,"\n")
# Out:
# iteration #  1
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.92856635]
#  [0.92656627]
#  [0.92699137]
#  [0.92856635]]
#
# cost
#  1.3575132649332597
#
# iteration #  2
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.75984119]
#  [0.75736901]
#  [0.75788553]
#  [0.75984119]]
#
# cost
#  0.8520093387318992
#
# iteration #  3
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.58067951]
#  [0.5797046 ]
#  [0.57988745]
#  [0.58067951]]
#
# cost
#  0.7070993463407985
#
# iteration #  4
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.51689829]
#  [0.51663776]
#  [0.51666318]
#  [0.51689829]]
#
# cost
#  0.6939583853121393
#
# iteration #  5
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.50193798]
#  [0.50186171]
#  [0.50184697]
#  [0.50193798]]
#
# cost
#  0.6932380161653111
#
# iteration #  6
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49853844]
#  [0.49851819]
#  [0.49849164]
#  [0.49853844]]
#
# cost
#  0.6931850810844383
#
# iteration #  7
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.4977611 ]
#  [0.49776777]
#  [0.49773583]
#  [0.4977611 ]]
#
# cost
#  0.693166555432002
#
# iteration #  8
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49757911]
#  [0.49760604]
#  [0.49757018]
#  [0.49757911]]
#
# cost
#  0.6931498614528919
#
# iteration #  9
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49753246]
#  [0.4975781 ]
#  [0.49753864]
#  [0.49753246]]
#
# cost
#  0.6931333167632183
#
# iteration #  10
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49751658]
#  [0.49758053]
#  [0.49753757]
#  [0.49751658]]
#
# cost
#  0.6931168327955824
#
# iteration #  11
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49750769]
#  [0.49758982]
#  [0.49754338]
#  [0.49750769]]
#
# cost
#  0.6931004033588289
#
# iteration #  12
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49750038]
#  [0.49760061]
#  [0.4975507 ]
#  [0.49750038]]
#
# cost
#  0.693084026526841
#
# iteration #  13
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.4974934 ]
#  [0.49761168]
#  [0.49755831]
#  [0.4974934 ]]
#
# cost
#  0.693067700604314
#
# iteration #  14
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49748648]
#  [0.49762275]
#  [0.49756593]
#  [0.49748648]]
#
# cost
#  0.6930514239199406
#
# iteration #  15
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49747956]
#  [0.49763377]
#  [0.49757351]
#  [0.49747956]]
#
# cost
#  0.6930351948159256
#
# iteration #  16
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49747261]
#  [0.49764471]
#  [0.49758102]
#  [0.49747261]]
#
# cost
#  0.6930190116471968
#
# iteration #  17
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49746563]
#  [0.49765558]
#  [0.49758846]
#  [0.49746563]]
#
# cost
#  0.6930028727810115
#
# iteration #  18
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49745863]
#  [0.49766637]
#  [0.49759584]
#  [0.49745863]]
#
# cost
#  0.6929867765965609
#
# iteration #  19
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.4974516 ]
#  [0.49767709]
#  [0.49760315]
#  [0.4974516 ]]
#
# cost
#  0.6929707214845747
#
# iteration #  20
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49744454]
#  [0.49768773]
#  [0.49761039]
#  [0.49744454]]
#
# cost
#  0.6929547058469298
#
# iteration #  21
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49743744]
#  [0.49769831]
#  [0.49761758]
#  [0.49743744]]
#
# cost
#  0.6929387280962618
#
# iteration #  22
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49743032]
#  [0.49770881]
#  [0.4976247 ]
#  [0.49743032]]
#
# cost
#  0.6929227866555845
#
# iteration #  23
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49742316]
#  [0.49771925]
#  [0.49763176]
#  [0.49742316]]
#
# cost
#  0.692906879957911
#
# iteration #  24
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49741597]
#  [0.49772961]
#  [0.49763876]
#  [0.49741597]]
#
# cost
#  0.6928910064458818
#
# iteration #  25
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49740875]
#  [0.4977399 ]
#  [0.4976457 ]
#  [0.49740875]]
#
# cost
#  0.6928751645713966
#
# iteration #  26
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.4974015 ]
#  [0.49775013]
#  [0.49765258]
#  [0.4974015 ]]
#
# cost
#  0.6928593527952498
#
# iteration #  27
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49739421]
#  [0.49776029]
#  [0.4976594 ]
#  [0.49739421]]
#
# cost
#  0.6928435695867706
#
# iteration #  28
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49738688]
#  [0.49777039]
#  [0.49766617]
#  [0.49738688]]
#
# cost
#  0.6928278134234676
#
# iteration #  29
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49737952]
#  [0.49778042]
#  [0.49767288]
#  [0.49737952]]
#
# cost
#  0.6928120827906751
#
# iteration #  30
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49737212]
#  [0.49779038]
#  [0.49767954]
#  [0.49737212]]
#
# cost
#  0.692796376181206
#
# iteration #  31
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49736469]
#  [0.49780028]
#  [0.49768614]
#  [0.49736469]]
#
# cost
#  0.6927806920950057
#
# iteration #  32
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49735722]
#  [0.49781012]
#  [0.49769269]
#  [0.49735722]]
#
# cost
#  0.6927650290388094
#
# iteration #  33
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49734971]
#  [0.4978199 ]
#  [0.49769918]
#  [0.49734971]]
#
# cost
#  0.6927493855258043
#
# iteration #  34
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49734216]
#  [0.49782962]
#  [0.49770563]
#  [0.49734216]]
#
# cost
#  0.6927337600752923
#
# iteration #  35
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49733457]
#  [0.49783927]
#  [0.49771202]
#  [0.49733457]]
#
# cost
#  0.6927181512123577
#
# iteration #  36
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49732694]
#  [0.49784887]
#  [0.49771836]
#  [0.49732694]]
#
# cost
#  0.6927025574675356
#
# iteration #  37
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49731927]
#  [0.49785841]
#  [0.49772466]
#  [0.49731927]]
#
# cost
#  0.6926869773764833
#
# iteration #  38
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49731156]
#  [0.49786789]
#  [0.4977309 ]
#  [0.49731156]]
#
# cost
#  0.6926714094796558
#
# iteration #  39
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49730381]
#  [0.49787731]
#  [0.4977371 ]
#  [0.49730381]]
#
# cost
#  0.6926558523219806
#
# iteration #  40
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49729601]
#  [0.49788667]
#  [0.49774326]
#  [0.49729601]]
#
# cost
#  0.692640304452536
#
# iteration #  41
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49728817]
#  [0.49789598]
#  [0.49774936]
#  [0.49728817]]
#
# cost
#  0.6926247644242309
#
# iteration #  42
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49728028]
#  [0.49790524]
#  [0.49775542]
#  [0.49728028]]
#
# cost
#  0.6926092307934877
#
# iteration #  43
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49727235]
#  [0.49791444]
#  [0.49776144]
#  [0.49727235]]
#
# cost
#  0.6925937021199238
#
# iteration #  44
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49726438]
#  [0.49792359]
#  [0.49776742]
#  [0.49726438]]
#
# cost
#  0.6925781769660376
#
# iteration #  45
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49725636]
#  [0.49793268]
#  [0.49777335]
#  [0.49725636]]
#
# cost
#  0.6925626538968945
#
# iteration #  46
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49724829]
#  [0.49794172]
#  [0.49777924]
#  [0.49724829]]
#
# cost
#  0.6925471314798126
#
# iteration #  47
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49724017]
#  [0.49795072]
#  [0.49778509]
#  [0.49724017]]
#
# cost
#  0.6925316082840521
#
# iteration #  48
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49723201]
#  [0.49795966]
#  [0.49779089]
#  [0.49723201]]
#
# cost
#  0.6925160828805045
#
# iteration #  49
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.4972238 ]
#  [0.49796855]
#  [0.49779666]
#  [0.4972238 ]]
#
# cost
#  0.6925005538413812
#
# iteration #  50
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49721553]
#  [0.49797739]
#  [0.49780239]
#  [0.49721553]]
#
# cost
#  0.6924850197399051
#
# iteration #  51
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49720722]
#  [0.49798618]
#  [0.49780809]
#  [0.49720722]]
#
# cost
#  0.6924694791500006
#
# iteration #  52
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49719886]
#  [0.49799493]
#  [0.49781374]
#  [0.49719886]]
#
# cost
#  0.692453930645985
#
# iteration #  53
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49719044]
#  [0.49800363]
#  [0.49781936]
#  [0.49719044]]
#
# cost
#  0.6924383728022601
#
# iteration #  54
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49718197]
#  [0.49801228]
#  [0.49782494]
#  [0.49718197]]
#
# cost
#  0.6924228041930033
#
# iteration #  55
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49717345]
#  [0.49802089]
#  [0.49783049]
#  [0.49717345]]
#
# cost
#  0.6924072233918592
#
# iteration #  56
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49716487]
#  [0.49802945]
#  [0.497836  ]
#  [0.49716487]]
#
# cost
#  0.6923916289716305
#
# iteration #  57
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49715624]
#  [0.49803797]
#  [0.49784148]
#  [0.49715624]]
#
# cost
#  0.6923760195039699
#
# iteration #  58
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49714756]
#  [0.49804644]
#  [0.49784693]
#  [0.49714756]]
#
# cost
#  0.6923603935590689
#
# iteration #  59
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49713882]
#  [0.49805488]
#  [0.49785235]
#  [0.49713882]]
#
# cost
#  0.6923447497053488
#
# iteration #  60
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49713002]
#  [0.49806327]
#  [0.49785773]
#  [0.49713002]]
#
# cost
#  0.6923290865091489
#
# iteration #  61
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49712116]
#  [0.49807161]
#  [0.49786309]
#  [0.49712116]]
#
# cost
#  0.6923134025344165
#
# iteration #  62
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49711225]
#  [0.49807992]
#  [0.49786841]
#  [0.49711225]]
#
# cost
#  0.6922976963423916
#
# iteration #  63
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49710328]
#  [0.49808819]
#  [0.49787371]
#  [0.49710328]]
#
# cost
#  0.6922819664912949
#
# iteration #  64
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49709424]
#  [0.49809642]
#  [0.49787897]
#  [0.49709424]]
#
# cost
#  0.6922662115360122
#
# iteration #  65
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49708515]
#  [0.49810461]
#  [0.49788421]
#  [0.49708515]]
#
# cost
#  0.6922504300277771
#
# iteration #  66
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.497076  ]
#  [0.49811276]
#  [0.49788943]
#  [0.497076  ]]
#
# cost
#  0.6922346205138543
#
# iteration #  67
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49706678]
#  [0.49812087]
#  [0.49789461]
#  [0.49706678]]
#
# cost
#  0.6922187815372188
#
# iteration #  68
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.4970575 ]
#  [0.49812895]
#  [0.49789978]
#  [0.4970575 ]]
#
# cost
#  0.6922029116362342
#
# iteration #  69
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49704816]
#  [0.49813699]
#  [0.49790491]
#  [0.49704816]]
#
# cost
#  0.6921870093443299
#
# iteration #  70
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49703875]
#  [0.498145  ]
#  [0.49791002]
#  [0.49703875]]
#
# cost
#  0.6921710731896757
#
# iteration #  71
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49702928]
#  [0.49815297]
#  [0.49791511]
#  [0.49702928]]
#
# cost
#  0.6921551016948526
#
# iteration #  72
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49701975]
#  [0.4981609 ]
#  [0.49792018]
#  [0.49701975]]
#
# cost
#  0.6921390933765246
#
# iteration #  73
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49701014]
#  [0.49816881]
#  [0.49792523]
#  [0.49701014]]
#
# cost
#  0.6921230467451034
#
# iteration #  74
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49700047]
#  [0.49817668]
#  [0.49793025]
#  [0.49700047]]
#
# cost
#  0.6921069603044157
#
# iteration #  75
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49699073]
#  [0.49818452]
#  [0.49793526]
#  [0.49699073]]
#
# cost
#  0.6920908325513632
#
# iteration #  76
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49698092]
#  [0.49819232]
#  [0.49794024]
#  [0.49698092]]
#
# cost
#  0.692074661975582
#
# iteration #  77
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49697104]
#  [0.4982001 ]
#  [0.49794521]
#  [0.49697104]]
#
# cost
#  0.6920584470590979
#
# iteration #  78
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49696109]
#  [0.49820785]
#  [0.49795015]
#  [0.49696109]]
#
# cost
#  0.6920421862759805
#
# iteration #  79
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49695107]
#  [0.49821556]
#  [0.49795508]
#  [0.49695107]]
#
# cost
#  0.6920258780919892
#
# iteration #  80
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49694098]
#  [0.49822325]
#  [0.49796   ]
#  [0.49694098]]
#
# cost
#  0.692009520964222
#
# iteration #  81
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49693081]
#  [0.49823091]
#  [0.4979649 ]
#  [0.49693081]]
#
# cost
#  0.6919931133407539
#
# iteration #  82
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49692057]
#  [0.49823854]
#  [0.49796978]
#  [0.49692057]]
#
# cost
#  0.6919766536602775
#
# iteration #  83
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49691025]
#  [0.49824615]
#  [0.49797465]
#  [0.49691025]]
#
# cost
#  0.6919601403517349
#
# iteration #  84
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49689986]
#  [0.49825373]
#  [0.4979795 ]
#  [0.49689986]]
#
# cost
#  0.691943571833948
#
# iteration #  85
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49688939]
#  [0.49826128]
#  [0.49798434]
#  [0.49688939]]
#
# cost
#  0.6919269465152429
#
# iteration #  86
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49687884]
#  [0.49826881]
#  [0.49798917]
#  [0.49687884]]
#
# cost
#  0.6919102627930708
#
# iteration #  87
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49686822]
#  [0.49827631]
#  [0.49799399]
#  [0.49686822]]
#
# cost
#  0.6918935190536233
#
# iteration #  88
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49685751]
#  [0.4982838 ]
#  [0.4979988 ]
#  [0.49685751]]
#
# cost
#  0.6918767136714439
#
# iteration #  89
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49684673]
#  [0.49829125]
#  [0.4980036 ]
#  [0.49684673]]
#
# cost
#  0.6918598450090325
#
# iteration #  90
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49683586]
#  [0.49829869]
#  [0.49800838]
#  [0.49683586]]
#
# cost
#  0.6918429114164456
#
# iteration #  91
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49682491]
#  [0.4983061 ]
#  [0.49801316]
#  [0.49682491]]
#
# cost
#  0.6918259112308927
#
# iteration #  92
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49681388]
#  [0.4983135 ]
#  [0.49801794]
#  [0.49681388]]
#
# cost
#  0.6918088427763229
#
# iteration #  93
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49680276]
#  [0.49832087]
#  [0.4980227 ]
#  [0.49680276]]
#
# cost
#  0.6917917043630104
#
# iteration #  94
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49679155]
#  [0.49832822]
#  [0.49802746]
#  [0.49679155]]
#
# cost
#  0.6917744942871296
#
# iteration #  95
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49678026]
#  [0.49833556]
#  [0.49803221]
#  [0.49678026]]
#
# cost
#  0.6917572108303258
#
# iteration #  96
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49676889]
#  [0.49834287]
#  [0.49803696]
#  [0.49676889]]
#
# cost
#  0.6917398522592815
#
# iteration #  97
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49675742]
#  [0.49835017]
#  [0.49804171]
#  [0.49675742]]
#
# cost
#  0.6917224168252709
#
# iteration #  98
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49674587]
#  [0.49835746]
#  [0.49804645]
#  [0.49674587]]
#
# cost
#  0.6917049027637118
#
# iteration #  99
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49673422]
#  [0.49836472]
#  [0.49805119]
#  [0.49673422]]
#
# cost
#  0.6916873082937088
#
# iteration #  100
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49672248]
#  [0.49837197]
#  [0.49805593]
#  [0.49672248]]
#
# cost
#  0.6916696316175888
#
# iteration #  101
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49671065]
#  [0.49837921]
#  [0.49806067]
#  [0.49671065]]
#
# cost
#  0.6916518709204277
#
# iteration #  102
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49669873]
#  [0.49838643]
#  [0.49806541]
#  [0.49669873]]
#
# cost
#  0.6916340243695731
#
# iteration #  103
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49668671]
#  [0.49839364]
#  [0.49807015]
#  [0.49668671]]
#
# cost
#  0.6916160901141544
#
# iteration #  104
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.4966746 ]
#  [0.49840083]
#  [0.49807489]
#  [0.4966746 ]]
#
# cost
#  0.6915980662845862
#
# iteration #  105
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49666238]
#  [0.49840802]
#  [0.49807963]
#  [0.49666238]]
#
# cost
#  0.691579950992064
#
# iteration #  106
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49665007]
#  [0.49841519]
#  [0.49808438]
#  [0.49665007]]
#
# cost
#  0.6915617423280496
#
# iteration #  107
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49663766]
#  [0.49842235]
#  [0.49808913]
#  [0.49663766]]
#
# cost
#  0.6915434383637475
#
# iteration #  108
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49662515]
#  [0.4984295 ]
#  [0.49809389]
#  [0.49662515]]
#
# cost
#  0.6915250371495719
#
# iteration #  109
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49661254]
#  [0.49843664]
#  [0.49809865]
#  [0.49661254]]
#
# cost
#  0.6915065367146046
#
# iteration #  110
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49659983]
#  [0.49844378]
#  [0.49810342]
#  [0.49659983]]
#
# cost
#  0.6914879350660414
#
# iteration #  111
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49658701]
#  [0.4984509 ]
#  [0.4981082 ]
#  [0.49658701]]
#
# cost
#  0.691469230188629
#
# iteration #  112
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49657408]
#  [0.49845802]
#  [0.49811298]
#  [0.49657408]]
#
# cost
#  0.6914504200440914
#
# iteration #  113
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49656105]
#  [0.49846513]
#  [0.49811778]
#  [0.49656105]]
#
# cost
#  0.6914315025705438
#
# iteration #  114
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49654791]
#  [0.49847224]
#  [0.49812259]
#  [0.49654791]]
#
# cost
#  0.6914124756818971
#
# iteration #  115
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49653466]
#  [0.49847934]
#  [0.49812741]
#  [0.49653466]]
#
# cost
#  0.6913933372672489
#
# iteration #  116
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.4965213 ]
#  [0.49848644]
#  [0.49813224]
#  [0.4965213 ]]
#
# cost
#  0.6913740851902648
#
# iteration #  117
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49650783]
#  [0.49849354]
#  [0.49813708]
#  [0.49650783]]
#
# cost
#  0.6913547172885429
#
# iteration #  118
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49649424]
#  [0.49850063]
#  [0.49814194]
#  [0.49649424]]
#
# cost
#  0.6913352313729708
#
# iteration #  119
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49648054]
#  [0.49850772]
#  [0.49814681]
#  [0.49648054]]
#
# cost
#  0.6913156252270659
#
# iteration #  120
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49646673]
#  [0.49851481]
#  [0.4981517 ]
#  [0.49646673]]
#
# cost
#  0.6912958966063032
#
# iteration #  121
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.4964528 ]
#  [0.4985219 ]
#  [0.49815661]
#  [0.4964528 ]]
#
# cost
#  0.6912760432374281
#
# iteration #  122
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49643874]
#  [0.49852899]
#  [0.49816153]
#  [0.49643874]]
#
# cost
#  0.6912560628177579
#
# iteration #  123
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49642457]
#  [0.49853608]
#  [0.49816648]
#  [0.49642457]]
#
# cost
#  0.6912359530144642
#
# iteration #  124
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49641028]
#  [0.49854318]
#  [0.49817144]
#  [0.49641028]]
#
# cost
#  0.6912157114638431
#
# iteration #  125
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49639586]
#  [0.49855027]
#  [0.49817643]
#  [0.49639586]]
#
# cost
#  0.6911953357705689
#
# iteration #  126
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49638132]
#  [0.49855737]
#  [0.49818144]
#  [0.49638132]]
#
# cost
#  0.6911748235069315
#
# iteration #  127
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49636665]
#  [0.49856448]
#  [0.49818647]
#  [0.49636665]]
#
# cost
#  0.6911541722120564
#
# iteration #  128
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49635185]
#  [0.49857159]
#  [0.49819152]
#  [0.49635185]]
#
# cost
#  0.6911333793911093
#
# iteration #  129
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49633692]
#  [0.49857871]
#  [0.4981966 ]
#  [0.49633692]]
#
# cost
#  0.6911124425144818
#
# iteration #  130
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49632187]
#  [0.49858583]
#  [0.49820171]
#  [0.49632187]]
#
# cost
#  0.6910913590169592
#
# iteration #  131
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49630668]
#  [0.49859297]
#  [0.49820685]
#  [0.49630668]]
#
# cost
#  0.6910701262968694
#
# iteration #  132
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49629135]
#  [0.49860011]
#  [0.49821201]
#  [0.49629135]]
#
# cost
#  0.6910487417152129
#
# iteration #  133
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49627589]
#  [0.49860726]
#  [0.4982172 ]
#  [0.49627589]]
#
# cost
#  0.6910272025947739
#
# iteration #  134
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49626029]
#  [0.49861442]
#  [0.49822243]
#  [0.49626029]]
#
# cost
#  0.6910055062192086
#
# iteration #  135
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49624455]
#  [0.4986216 ]
#  [0.49822769]
#  [0.49624455]]
#
# cost
#  0.6909836498321147
#
# iteration #  136
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49622867]
#  [0.49862878]
#  [0.49823298]
#  [0.49622867]]
#
# cost
#  0.690961630636078
#
# iteration #  137
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49621265]
#  [0.49863599]
#  [0.49823831]
#  [0.49621265]]
#
# cost
#  0.6909394457916981
#
# iteration #  138
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49619648]
#  [0.4986432 ]
#  [0.49824367]
#  [0.49619648]]
#
# cost
#  0.6909170924165894
#
# iteration #  139
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49618017]
#  [0.49865043]
#  [0.49824907]
#  [0.49618017]]
#
# cost
#  0.6908945675843595
#
# iteration #  140
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49616371]
#  [0.49865768]
#  [0.49825451]
#  [0.49616371]]
#
# cost
#  0.6908718683235637
#
# iteration #  141
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49614709]
#  [0.49866494]
#  [0.49825998]
#  [0.49614709]]
#
# cost
#  0.6908489916166334
#
# iteration #  142
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49613033]
#  [0.49867222]
#  [0.4982655 ]
#  [0.49613033]]
#
# cost
#  0.690825934398779
#
# iteration #  143
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49611341]
#  [0.49867953]
#  [0.49827106]
#  [0.49611341]]
#
# cost
#  0.6908026935568671
#
# iteration #  144
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49609633]
#  [0.49868685]
#  [0.49827667]
#  [0.49609633]]
#
# cost
#  0.6907792659282695
#
# iteration #  145
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.4960791 ]
#  [0.49869419]
#  [0.49828232]
#  [0.4960791 ]]
#
# cost
#  0.6907556482996835
#
# iteration #  146
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.4960617 ]
#  [0.49870156]
#  [0.49828802]
#  [0.4960617 ]]
#
# cost
#  0.6907318374059246
#
# iteration #  147
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49604415]
#  [0.49870895]
#  [0.49829376]
#  [0.49604415]]
#
# cost
#  0.6907078299286876
#
# iteration #  148
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49602642]
#  [0.49871636]
#  [0.49829956]
#  [0.49602642]]
#
# cost
#  0.6906836224952793
#
# iteration #  149
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49600853]
#  [0.4987238 ]
#  [0.49830541]
#  [0.49600853]]
#
# cost
#  0.6906592116773156
#
# iteration #  150
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49599048]
#  [0.49873127]
#  [0.49831131]
#  [0.49599048]]
#
# cost
#  0.6906345939893903
#
# iteration #  151
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49597225]
#  [0.49873877]
#  [0.49831726]
#  [0.49597225]]
#
# cost
#  0.6906097658877061
#
# iteration #  152
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49595384]
#  [0.49874629]
#  [0.49832327]
#  [0.49595384]]
#
# cost
#  0.6905847237686742
#
# iteration #  153
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49593526]
#  [0.49875385]
#  [0.49832933]
#  [0.49593526]]
#
# cost
#  0.6905594639674753
#
# iteration #  154
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49591651]
#  [0.49876143]
#  [0.49833546]
#  [0.49591651]]
#
# cost
#  0.6905339827565854
#
# iteration #  155
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49589757]
#  [0.49876905]
#  [0.49834165]
#  [0.49589757]]
#
# cost
#  0.6905082763442631
#
# iteration #  156
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49587845]
#  [0.4987767 ]
#  [0.49834789]
#  [0.49587845]]
#
# cost
#  0.6904823408729966
#
# iteration #  157
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49585914]
#  [0.49878439]
#  [0.49835421]
#  [0.49585914]]
#
# cost
#  0.6904561724179118
#
# iteration #  158
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49583965]
#  [0.49879211]
#  [0.49836058]
#  [0.49583965]]
#
# cost
#  0.6904297669851377
#
# iteration #  159
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49581996]
#  [0.49879988]
#  [0.49836703]
#  [0.49581996]]
#
# cost
#  0.6904031205101284
#
# iteration #  160
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49580008]
#  [0.49880768]
#  [0.49837355]
#  [0.49580008]]
#
# cost
#  0.6903762288559416
#
# iteration #  161
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49578001]
#  [0.49881552]
#  [0.49838013]
#  [0.49578001]]
#
# cost
#  0.6903490878114698
#
# iteration #  162
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49575973]
#  [0.4988234 ]
#  [0.49838679]
#  [0.49575973]]
#
# cost
#  0.6903216930896265
#
# iteration #  163
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49573926]
#  [0.49883132]
#  [0.49839353]
#  [0.49573926]]
#
# cost
#  0.6902940403254817
#
# iteration #  164
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49571858]
#  [0.49883929]
#  [0.49840034]
#  [0.49571858]]
#
# cost
#  0.6902661250743467
#
# iteration #  165
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49569769]
#  [0.49884731]
#  [0.49840723]
#  [0.49569769]]
#
# cost
#  0.6902379428098089
#
# iteration #  166
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49567659]
#  [0.49885537]
#  [0.4984142 ]
#  [0.49567659]]
#
# cost
#  0.6902094889217121
#
# iteration #  167
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49565528]
#  [0.49886348]
#  [0.49842126]
#  [0.49565528]]
#
# cost
#  0.6901807587140799
#
# iteration #  168
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49563376]
#  [0.49887164]
#  [0.4984284 ]
#  [0.49563376]]
#
# cost
#  0.6901517474029849
#
# iteration #  169
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49561201]
#  [0.49887986]
#  [0.49843563]
#  [0.49561201]]
#
# cost
#  0.6901224501143564
#
# iteration #  170
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49559005]
#  [0.49888812]
#  [0.49844294]
#  [0.49559005]]
#
# cost
#  0.6900928618817287
#
# iteration #  171
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49556785]
#  [0.49889644]
#  [0.49845035]
#  [0.49556785]]
#
# cost
#  0.6900629776439258
#
# iteration #  172
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49554543]
#  [0.49890482]
#  [0.49845786]
#  [0.49554543]]
#
# cost
#  0.690032792242681
#
# iteration #  173
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49552278]
#  [0.49891326]
#  [0.49846546]
#  [0.49552278]]
#
# cost
#  0.6900023004201903
#
# iteration #  174
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49549989]
#  [0.49892175]
#  [0.49847316]
#  [0.49549989]]
#
# cost
#  0.6899714968165964
#
# iteration #  175
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49547676]
#  [0.49893031]
#  [0.49848096]
#  [0.49547676]]
#
# cost
#  0.6899403759674001
#
# iteration #  176
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49545339]
#  [0.49893893]
#  [0.49848887]
#  [0.49545339]]
#
# cost
#  0.689908932300798
#
# iteration #  177
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49542978]
#  [0.49894761]
#  [0.49849688]
#  [0.49542978]]
#
# cost
#  0.6898771601349456
#
# iteration #  178
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49540591]
#  [0.49895636]
#  [0.498505  ]
#  [0.49540591]]
#
# cost
#  0.689845053675139
#
# iteration #  179
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.4953818 ]
#  [0.49896518]
#  [0.49851324]
#  [0.4953818 ]]
#
# cost
#  0.6898126070109164
#
# iteration #  180
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49535742]
#  [0.49897407]
#  [0.49852159]
#  [0.49535742]]
#
# cost
#  0.6897798141130752
#
# iteration #  181
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49533278]
#  [0.49898303]
#  [0.49853005]
#  [0.49533278]]
#
# cost
#  0.6897466688306009
#
# iteration #  182
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49530788]
#  [0.49899207]
#  [0.49853864]
#  [0.49530788]]
#
# cost
#  0.6897131648875071
#
# iteration #  183
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49528271]
#  [0.49900118]
#  [0.49854735]
#  [0.49528271]]
#
# cost
#  0.689679295879582
#
# iteration #  184
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49525727]
#  [0.49901037]
#  [0.49855619]
#  [0.49525727]]
#
# cost
#  0.6896450552710375
#
# iteration #  185
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49523155]
#  [0.49901964]
#  [0.49856516]
#  [0.49523155]]
#
# cost
#  0.6896104363910592
#
# iteration #  186
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49520555]
#  [0.499029  ]
#  [0.49857426]
#  [0.49520555]]
#
# cost
#  0.6895754324302543
#
# iteration #  187
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49517926]
#  [0.49903844]
#  [0.49858349]
#  [0.49517926]]
#
# cost
#  0.6895400364369901
#
# iteration #  188
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49515268]
#  [0.49904796]
#  [0.49859287]
#  [0.49515268]]
#
# cost
#  0.6895042413136253
#
# iteration #  189
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49512581]
#  [0.49905757]
#  [0.49860239]
#  [0.49512581]]
#
# cost
#  0.6894680398126242
#
# iteration #  190
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49509864]
#  [0.49906728]
#  [0.49861205]
#  [0.49509864]]
#
# cost
#  0.6894314245325539
#
# iteration #  191
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49507116]
#  [0.49907708]
#  [0.49862186]
#  [0.49507116]]
#
# cost
#  0.6893943879139595
#
# iteration #  192
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49504338]
#  [0.49908697]
#  [0.49863183]
#  [0.49504338]]
#
# cost
#  0.6893569222351108
#
# iteration #  193
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49501528]
#  [0.49909696]
#  [0.49864195]
#  [0.49501528]]
#
# cost
#  0.6893190196076202
#
# iteration #  194
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49498686]
#  [0.49910706]
#  [0.49865224]
#  [0.49498686]]
#
# cost
#  0.6892806719719213
#
# iteration #  195
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49495812]
#  [0.49911725]
#  [0.49866269]
#  [0.49495812]]
#
# cost
#  0.6892418710926098
#
# iteration #  196
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49492905]
#  [0.49912756]
#  [0.49867331]
#  [0.49492905]]
#
# cost
#  0.6892026085536371
#
# iteration #  197
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49489965]
#  [0.49913797]
#  [0.4986841 ]
#  [0.49489965]]
#
# cost
#  0.6891628757533526
#
# iteration #  198
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49486991]
#  [0.49914849]
#  [0.49869506]
#  [0.49486991]]
#
# cost
#  0.6891226638993893
#
# iteration #  199
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49483982]
#  [0.49915913]
#  [0.49870621]
#  [0.49483982]]
#
# cost
#  0.6890819640033881
#
# iteration #  200
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49480938]
#  [0.49916988]
#  [0.49871755]
#  [0.49480938]]
#
# cost
#  0.689040766875553
#
# iteration #  201
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49477858]
#  [0.49918076]
#  [0.49872907]
#  [0.49477858]]
#
# cost
#  0.6889990631190319
#
# iteration #  202
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49474742]
#  [0.49919175]
#  [0.49874079]
#  [0.49474742]]
#
# cost
#  0.6889568431241164
#
# iteration #  203
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49471589]
#  [0.49920288]
#  [0.49875271]
#  [0.49471589]]
#
# cost
#  0.6889140970622553
#
# iteration #  204
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49468398]
#  [0.49921413]
#  [0.49876484]
#  [0.49468398]]
#
# cost
#  0.6888708148798718
#
# iteration #  205
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.4946517 ]
#  [0.49922551]
#  [0.49877717]
#  [0.4946517 ]]
#
# cost
#  0.6888269862919805
#
# iteration #  206
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49461902]
#  [0.49923704]
#  [0.49878972]
#  [0.49461902]]
#
# cost
#  0.6887826007755945
#
# iteration #  207
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49458595]
#  [0.49924869]
#  [0.49880248]
#  [0.49458595]]
#
# cost
#  0.6887376475629141
#
# iteration #  208
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49455248]
#  [0.4992605 ]
#  [0.49881548]
#  [0.49455248]]
#
# cost
#  0.6886921156342931
#
# iteration #  209
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.4945186 ]
#  [0.49927244]
#  [0.4988287 ]
#  [0.4945186 ]]
#
# cost
#  0.6886459937109687
#
# iteration #  210
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49448431]
#  [0.49928454]
#  [0.49884216]
#  [0.49448431]]
#
# cost
#  0.6885992702475485
#
# iteration #  211
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49444959]
#  [0.49929679]
#  [0.49885586]
#  [0.49444959]]
#
# cost
#  0.6885519334242477
#
# iteration #  212
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49441445]
#  [0.4993092 ]
#  [0.49886981]
#  [0.49441445]]
#
# cost
#  0.6885039711388614
#
# iteration #  213
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49437886]
#  [0.49932177]
#  [0.49888401]
#  [0.49437886]]
#
# cost
#  0.6884553709984675
#
# iteration #  214
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49434283]
#  [0.4993345 ]
#  [0.49889848]
#  [0.49434283]]
#
# cost
#  0.688406120310846
#
# iteration #  215
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49430635]
#  [0.4993474 ]
#  [0.49891321]
#  [0.49430635]]
#
# cost
#  0.6883562060756041
#
# iteration #  216
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49426941]
#  [0.49936047]
#  [0.49892821]
#  [0.49426941]]
#
# cost
#  0.6883056149749978
#
# iteration #  217
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49423199]
#  [0.49937373]
#  [0.4989435 ]
#  [0.49423199]]
#
# cost
#  0.6882543333644365
#
# iteration #  218
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.4941941 ]
#  [0.49938716]
#  [0.49895907]
#  [0.4941941 ]]
#
# cost
#  0.6882023472626562
#
# iteration #  219
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49415572]
#  [0.49940078]
#  [0.49897494]
#  [0.49415572]]
#
# cost
#  0.6881496423415518
#
# iteration #  220
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49411685]
#  [0.49941459]
#  [0.4989911 ]
#  [0.49411685]]
#
# cost
#  0.6880962039156541
#
# iteration #  221
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49407747]
#  [0.49942859]
#  [0.49900758]
#  [0.49407747]]
#
# cost
#  0.6880420169312331
#
# iteration #  222
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49403757]
#  [0.4994428 ]
#  [0.49902438]
#  [0.49403757]]
#
# cost
#  0.6879870659550194
#
# iteration #  223
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49399715]
#  [0.49945721]
#  [0.4990415 ]
#  [0.49399715]]
#
# cost
#  0.6879313351625231
#
# iteration #  224
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.4939562 ]
#  [0.49947183]
#  [0.49905895]
#  [0.4939562 ]]
#
# cost
#  0.687874808325936
#
# iteration #  225
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.4939147 ]
#  [0.49948666]
#  [0.49907675]
#  [0.4939147 ]]
#
# cost
#  0.6878174688015972
#
# iteration #  226
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49387265]
#  [0.49950172]
#  [0.4990949 ]
#  [0.49387265]]
#
# cost
#  0.6877592995170123
#
# iteration #  227
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49383004]
#  [0.499517  ]
#  [0.49911341]
#  [0.49383004]]
#
# cost
#  0.6877002829573969
#
# iteration #  228
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49378685]
#  [0.49953252]
#  [0.49913228]
#  [0.49378685]]
#
# cost
#  0.6876404011517319
#
# iteration #  229
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49374307]
#  [0.49954827]
#  [0.49915154]
#  [0.49374307]]
#
# cost
#  0.6875796356583084
#
# iteration #  230
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49369869]
#  [0.49956426]
#  [0.49917118]
#  [0.49369869]]
#
# cost
#  0.6875179675497426
#
# iteration #  231
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49365371]
#  [0.49958051]
#  [0.49919122]
#  [0.49365371]]
#
# cost
#  0.6874553773974337
#
# iteration #  232
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.4936081 ]
#  [0.49959701]
#  [0.49921167]
#  [0.4936081 ]]
#
# cost
#  0.6873918452554489
#
# iteration #  233
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49356186]
#  [0.49961377]
#  [0.49923254]
#  [0.49356186]]
#
# cost
#  0.6873273506438013
#
# iteration #  234
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49351497]
#  [0.49963081]
#  [0.49925384]
#  [0.49351497]]
#
# cost
#  0.6872618725311074
#
# iteration #  235
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49346743]
#  [0.49964812]
#  [0.49927558]
#  [0.49346743]]
#
# cost
#  0.6871953893165844
#
# iteration #  236
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49341921]
#  [0.49966571]
#  [0.49929778]
#  [0.49341921]]
#
# cost
#  0.6871278788113706
#
# iteration #  237
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.4933703 ]
#  [0.49968359]
#  [0.49932044]
#  [0.4933703 ]]
#
# cost
#  0.6870593182191318
#
# iteration #  238
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49332069]
#  [0.49970177]
#  [0.49934357]
#  [0.49332069]]
#
# cost
#  0.6869896841159269
#
# iteration #  239
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49327037]
#  [0.49972025]
#  [0.4993672 ]
#  [0.49327037]]
#
# cost
#  0.6869189524292992
#
# iteration #  240
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49321932]
#  [0.49973905]
#  [0.49939133]
#  [0.49321932]]
#
# cost
#  0.6868470984165589
#
# iteration #  241
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49316753]
#  [0.49975816]
#  [0.49941598]
#  [0.49316753]]
#
# cost
#  0.6867740966422236
#
# iteration #  242
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49311497]
#  [0.49977761]
#  [0.49944116]
#  [0.49311497]]
#
# cost
#  0.6866999209545778
#
# iteration #  243
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49306164]
#  [0.49979739]
#  [0.49946688]
#  [0.49306164]]
#
# cost
#  0.6866245444613122
#
# iteration #  244
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49300751]
#  [0.49981752]
#  [0.49949316]
#  [0.49300751]]
#
# cost
#  0.6865479395042026
#
# iteration #  245
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49295258]
#  [0.49983801]
#  [0.49952002]
#  [0.49295258]]
#
# cost
#  0.686470077632787
#
# iteration #  246
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49289682]
#  [0.49985886]
#  [0.49954747]
#  [0.49289682]]
#
# cost
#  0.6863909295769922
#
# iteration #  247
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49284021]
#  [0.49988008]
#  [0.49957553]
#  [0.49284021]]
#
# cost
#  0.6863104652186673
#
# iteration #  248
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49278275]
#  [0.49990169]
#  [0.49960421]
#  [0.49278275]]
#
# cost
#  0.6862286535619686
#
# iteration #  249
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.4927244 ]
#  [0.49992369]
#  [0.49963353]
#  [0.4927244 ]]
#
# cost
#  0.6861454627025511
#
# iteration #  250
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49266515]
#  [0.4999461 ]
#  [0.49966351]
#  [0.49266515]]
#
# cost
#  0.6860608597955045
#
# iteration #  251
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49260497]
#  [0.49996892]
#  [0.49969417]
#  [0.49260497]]
#
# cost
#  0.6859748110219822
#
# iteration #  252
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49254386]
#  [0.49999217]
#  [0.49972552]
#  [0.49254386]]
#
# cost
#  0.6858872815544585
#
# iteration #  253
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49248178]
#  [0.50001585]
#  [0.49975759]
#  [0.49248178]]
#
# cost
#  0.6857982355205534
#
# iteration #  254
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49241872]
#  [0.50003999]
#  [0.4997904 ]
#  [0.49241872]]
#
# cost
#  0.685707635965357
#
# iteration #  255
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49235466]
#  [0.50006458]
#  [0.49982396]
#  [0.49235466]]
#
# cost
#  0.6856154448121828
#
# iteration #  256
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49228956]
#  [0.50008965]
#  [0.4998583 ]
#  [0.49228956]]
#
# cost
#  0.685521622821679
#
# iteration #  257
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49222341]
#  [0.50011521]
#  [0.49989345]
#  [0.49222341]]
#
# cost
#  0.6854261295492144
#
# iteration #  258
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49215618]
#  [0.50014126]
#  [0.49992941]
#  [0.49215618]]
#
# cost
#  0.6853289233004656
#
# iteration #  259
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49208785]
#  [0.50016783]
#  [0.49996623]
#  [0.49208785]]
#
# cost
#  0.6852299610851106
#
# iteration #  260
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49201839]
#  [0.50019493]
#  [0.50000392]
#  [0.49201839]]
#
# cost
#  0.6851291985685454
#
# iteration #  261
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49194777]
#  [0.50022257]
#  [0.50004251]
#  [0.49194777]]
#
# cost
#  0.6850265900215262
#
# iteration #  262
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49187597]
#  [0.50025076]
#  [0.50008202]
#  [0.49187597]]
#
# cost
#  0.6849220882676348
#
# iteration #  263
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49180296]
#  [0.50027953]
#  [0.50012248]
#  [0.49180296]]
#
# cost
#  0.6848156446284653
#
# iteration #  264
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.4917287 ]
#  [0.50030889]
#  [0.50016393]
#  [0.4917287 ]]
#
# cost
#  0.6847072088664191
#
# iteration #  265
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49165318]
#  [0.50033885]
#  [0.50020638]
#  [0.49165318]]
#
# cost
#  0.6845967291249914
#
# iteration #  266
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49157635]
#  [0.50036943]
#  [0.50024987]
#  [0.49157635]]
#
# cost
#  0.6844841518664262
#
# iteration #  267
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49149819]
#  [0.50040066]
#  [0.50029444]
#  [0.49149819]]
#
# cost
#  0.6843694218066123
# iteration #  268
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49141867]
#  [0.50043254]
#  [0.50034011]
#  [0.49141867]]
#
# cost
#  0.6842524818470767
#
# iteration #  269
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49133774]
#  [0.5004651 ]
#  [0.50038691]
#  [0.49133774]]
#
# cost
#  0.6841332730039408
#
# iteration #  270
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49125537]
#  [0.50049835]
#  [0.50043489]
#  [0.49125537]]
#
# cost
#  0.6840117343336791
#
# iteration #  271
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49117153]
#  [0.50053232]
#  [0.50048408]
#  [0.49117153]]
#
# cost
#  0.683887802855524
#
# iteration #  272
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49108617]
#  [0.50056703]
#  [0.50053451]
#  [0.49108617]]
#
# cost
#  0.683761413470348
#
# iteration #  273
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49099927]
#  [0.5006025 ]
#  [0.50058622]
#  [0.49099927]]
#
# cost
#  0.6836324988758435
#
# iteration #  274
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49091078]
#  [0.50063874]
#  [0.50063926]
#  [0.49091078]]
#
# cost
#  0.6835009894778123
#
# iteration #  275
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49082065]
#  [0.50067579]
#  [0.50069367]
#  [0.49082065]]
#
# cost
#  0.6833668132973669
#
# iteration #  276
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49072885]
#  [0.50071367]
#  [0.50074948]
#  [0.49072885]]
#
# cost
#  0.6832298958738346
#
# iteration #  277
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49063533]
#  [0.5007524 ]
#  [0.50080675]
#  [0.49063533]]
#
# cost
#  0.6830901601631418
#
# iteration #  278
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49054004]
#  [0.500792  ]
#  [0.50086552]
#  [0.49054004]]
#
# cost
#  0.682947526431447
#
# iteration #  279
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49044294]
#  [0.50083251]
#  [0.50092584]
#  [0.49044294]]
#
# cost
#  0.6828019121437748
#
# iteration #  280
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49034398]
#  [0.50087395]
#  [0.50098776]
#  [0.49034398]]
#
# cost
#  0.6826532318473925
#
# iteration #  281
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.4902431 ]
#  [0.50091635]
#  [0.50105132]
#  [0.4902431 ]]
#
# cost
#  0.6825013970496505
#
# iteration #  282
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.49014026]
#  [0.50095974]
#  [0.50111659]
#  [0.49014026]]
#
# cost
#  0.682346316090004
#
# iteration #  283
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.4900354 ]
#  [0.50100414]
#  [0.50118362]
#  [0.4900354 ]]
#
# cost
#  0.6821878940059009
#
# iteration #  284
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.48992846]
#  [0.5010496 ]
#  [0.50125247]
#  [0.48992846]]
#
# cost
#  0.682026032392219
#
# iteration #  285
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.48981938]
#  [0.50109613]
#  [0.5013232 ]
#  [0.48981938]]
#
# cost
#  0.6818606292539074
#
# iteration #  286
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.48970811]
#  [0.50114378]
#  [0.50139587]
#  [0.48970811]]
#
# cost
#  0.6816915788514696
#
# iteration #  287
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.48959457]
#  [0.50119259]
#  [0.50147055]
#  [0.48959457]]
#
# cost
#  0.6815187715389094
#
# iteration #  288
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.48947872]
#  [0.50124258]
#  [0.5015473 ]
#  [0.48947872]]
#
# cost
#  0.6813420935937362
#
# iteration #  289
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.48936047]
#  [0.50129379]
#  [0.50162619]
#  [0.48936047]]
#
# cost
#  0.6811614270385975
#
# iteration #  290
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.48923975]
#  [0.50134627]
#  [0.50170731]
#  [0.48923975]]
#
# cost
#  0.6809766494540955
#
# iteration #  291
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.4891165 ]
#  [0.50140006]
#  [0.50179072]
#  [0.4891165 ]]
#
# cost
#  0.6807876337823054
#
# iteration #  292
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.48899064]
#  [0.50145518]
#  [0.5018765 ]
#  [0.48899064]]
#
# cost
#  0.6805942481204944
#
# iteration #  293
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.48886209]
#  [0.5015117 ]
#  [0.50196475]
#  [0.48886209]]
#
# cost
#  0.6803963555045056
#
# iteration #  294
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.48873077]
#  [0.50156966]
#  [0.50205553]
#  [0.48873077]]
#
# cost
#  0.6801938136812489
#
# iteration #  295
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.4885966 ]
#  [0.50162909]
#  [0.50214895]
#  [0.4885966 ]]
#
# cost
#  0.6799864748696968
#
# iteration #  296
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.48845948]
#  [0.50169006]
#  [0.50224509]
#  [0.48845948]]
#
# cost
#  0.6797741855097599
#
# iteration #  297
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.48831932]
#  [0.50175261]
#  [0.50234406]
#  [0.48831932]]
#
# cost
#  0.6795567859983754
#
# iteration #  298
# ...
#  [0.99229331]
#  [0.99725114]
#  [0.00404085]]
#
# cost
#  0.004646814003726087
#
# iteration #  904
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00403064]
#  [0.99231239]
#  [0.99725803]
#  [0.00403064]]
#
# cost
#  0.004635152100458874
#
# iteration #  905
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00402048]
#  [0.99233139]
#  [0.99726489]
#  [0.00402048]]
#
# cost
#  0.004623544989384633
#
# iteration #  906
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00401036]
#  [0.9923503 ]
#  [0.99727172]
#  [0.00401036]]
#
# cost
#  0.004611992296913358
#
# iteration #  907
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00400029]
#  [0.99236912]
#  [0.99727851]
#  [0.00400029]]
#
# cost
#  0.004600493652779341
#
# iteration #  908
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00399027]
#  [0.99238785]
#  [0.99728528]
#  [0.00399027]]
#
# cost
#  0.004589048690004687
#
# iteration #  909
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.0039803 ]
#  [0.9924065 ]
#  [0.99729201]
#  [0.0039803 ]]
#
# cost
#  0.004577657044863512
#
# iteration #  910
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00397037]
#  [0.99242506]
#  [0.99729871]
#  [0.00397037]]
#
# cost
#  0.004566318356846364
#
# iteration #  911
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00396049]
#  [0.99244354]
#  [0.99730538]
#  [0.00396049]]
#
# cost
#  0.004555032268625267
#
# iteration #  912
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00395066]
#  [0.99246193]
#  [0.99731202]
#  [0.00395066]]
#
# cost
#  0.004543798426019229
#
# iteration #  913
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00394087]
#  [0.99248024]
#  [0.99731862]
#  [0.00394087]]
#
# cost
#  0.0045326164779599335
#
# iteration #  914
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00393113]
#  [0.99249846]
#  [0.9973252 ]
#  [0.00393113]]
#
# cost
#  0.004521486076458598
#
# iteration #  915
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00392143]
#  [0.99251661]
#  [0.99733175]
#  [0.00392143]]
#
# cost
#  0.004510406876571853
#
# iteration #  916
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00391177]
#  [0.99253467]
#  [0.99733826]
#  [0.00391177]]
#
# cost
#  0.0044993785363699225
#
# iteration #  917
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00390216]
#  [0.99255265]
#  [0.99734475]
#  [0.00390216]]
#
# cost
#  0.004488400716903432
#
# iteration #  918
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.0038926 ]
#  [0.99257054]
#  [0.9973512 ]
#  [0.0038926 ]]
#
# cost
#  0.0044774730821720565
#
# iteration #  919
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00388308]
#  [0.99258836]
#  [0.99735763]
#  [0.00388308]]
#
# cost
#  0.004466595299092367
#
# iteration #  920
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.0038736 ]
#  [0.9926061 ]
#  [0.99736403]
#  [0.0038736 ]]
#
# cost
#  0.004455767037467218
#
# iteration #  921
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00386416]
#  [0.99262376]
#  [0.99737039]
#  [0.00386416]]
#
# cost
#  0.004444987969954501
#
# iteration #  922
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00385477]
#  [0.99264133]
#  [0.99737673]
#  [0.00385477]]
#
# cost
#  0.0044342577720371265
#
# iteration #  923
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00384542]
#  [0.99265883]
#  [0.99738304]
#  [0.00384542]]
#
# cost
#  0.0044235761219927365
#
# iteration #  924
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00383612]
#  [0.99267626]
#  [0.99738932]
#  [0.00383612]]
#
# cost
#  0.004412942700864234
#
# iteration #  925
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00382685]
#  [0.9926936 ]
#  [0.99739558]
#  [0.00382685]]
#
# cost
#  0.004402357192430565
#
# iteration #  926
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00381763]
#  [0.99271087]
#  [0.9974018 ]
#  [0.00381763]]
#
# cost
#  0.004391819283177728
#
# iteration #  927
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00380845]
#  [0.99272806]
#  [0.997408  ]
#  [0.00380845]]
#
# cost
#  0.004381328662270295
#
# iteration #  928
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00379931]
#  [0.99274518]
#  [0.99741417]
#  [0.00379931]]
#
# cost
#  0.004370885021523219
#
# iteration #  929
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00379021]
#  [0.99276222]
#  [0.99742031]
#  [0.00379021]]
# cost
#  0.0043604880553739424
#
# iteration #  930
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00378115]
#  [0.99277918]
#  [0.99742642]
#  [0.00378115]]
#
# cost
#  0.004350137460855279
#
# iteration #  931
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00377213]
#  [0.99279607]
#  [0.9974325 ]
#  [0.00377213]]
#
# cost
#  0.004339832937567757
#
# iteration #  932
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00376316]
#  [0.99281289]
#  [0.99743856]
#  [0.00376316]]
#
# cost
#  0.004329574187653259
#
# iteration #  933
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00375422]
#  [0.99282963]
#  [0.99744459]
#  [0.00375422]]
#
# cost
#  0.004319360915768195
#
# iteration #  934
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00374532]
#  [0.9928463 ]
#  [0.9974506 ]
#  [0.00374532]]
#
# cost
#  0.004309192829057973
#
# iteration #  935
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00373646]
#  [0.9928629 ]
#  [0.99745658]
#  [0.00373646]]
#
# cost
#  0.004299069637130277
#
# iteration #  936
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00372764]
#  [0.99287942]
#  [0.99746253]
#  [0.00372764]]
#
# cost
#  0.0042889910520303
#
# iteration #  937
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00371886]
#  [0.99289587]
#  [0.99746845]
#  [0.00371886]]
#
# cost
#  0.004278956788215609
#
# iteration #  938
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00371012]
#  [0.99291226]
#  [0.99747435]
#  [0.00371012]]
#
# cost
#  0.004268966562530288
#
# iteration #  939
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00370142]
#  [0.99292857]
#  [0.99748022]
#  [0.00370142]]
#
# cost
#  0.004259020094181838
#
# iteration #  940
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00369275]
#  [0.99294481]
#  [0.99748607]
#  [0.00369275]]
#
# cost
#  0.004249117104715694
#
# iteration #  941
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00368413]
#  [0.99296098]
#  [0.99749189]
#  [0.00368413]]
#
# cost
#  0.004239257317991769
#
# iteration #  942
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00367554]
#  [0.99297708]
#  [0.99749769]
#  [0.00367554]]
#
# cost
#  0.004229440460160708
#
# iteration #  943
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00366698]
#  [0.99299311]
#  [0.99750346]
#  [0.00366698]]
#
# cost
#  0.004219666259640672
#
# iteration #  944
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00365847]
#  [0.99300907]
#  [0.9975092 ]
#  [0.00365847]]
#
# cost
#  0.004209934447093591
#
# iteration #  945
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00364999]
#  [0.99302497]
#  [0.99751492]
#  [0.00364999]]
#
# cost
#  0.0042002447554033515
#
# iteration #  946
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00364155]
#  [0.9930408 ]
#  [0.99752062]
#  [0.00364155]]
#
# cost
#  0.0041905969196522
#
# iteration #  947
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00363315]
#  [0.99305656]
#  [0.99752629]
#  [0.00363315]]
#
# cost
#  0.00418099067709908
#
# iteration #  948
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00362478]
#  [0.99307225]
#  [0.99753193]
#  [0.00362478]]
#
# cost
#  0.004171425767157374
#
# iteration #  949
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00361645]
#  [0.99308788]
#  [0.99753756]
#  [0.00361645]]
#
# cost
#  0.0041619019313734774
#
# iteration #  950
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00360815]
#  [0.99310344]
#  [0.99754315]
#  [0.00360815]]
#
# cost
#  0.004152418913404771
#
# iteration #  951
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00359989]
#  [0.99311893]
#  [0.99754873]
#  [0.00359989]]
#
# cost
#  0.004142976458998672
#
# iteration #  952
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00359166]
#  [0.99313436]
#  [0.99755428]
#  [0.00359166]]
#
# cost
#  0.0041335743159718165
#
# iteration #  953
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00358348]
#  [0.99314972]
#  [0.9975598 ]
#  [0.00358348]]
#
# cost
#  0.004124212234189062
#
# iteration #  954
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00357532]
#  [0.99316502]
#  [0.9975653 ]
#  [0.00357532]]
#
# cost
#  0.004114889965543094
#
# iteration #  955
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.0035672 ]
#  [0.99318026]
#  [0.99757078]
#  [0.0035672 ]]
#
# cost
#  0.004105607263934159
#
# iteration #  956
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00355911]
#  [0.99319543]
#  [0.99757624]
#  [0.00355911]]
#
# cost
#  0.004096363885250099
#
# iteration #  957
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00355106]
#  [0.99321054]
#  [0.99758167]
#  [0.00355106]]
#
# cost
#  0.004087159587346479
#
# iteration #  958
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00354305]
#  [0.99322559]
#  [0.99758708]
#  [0.00354305]]
#
# cost
#  0.0040779941300273246
#
# iteration #  959
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00353506]
#  [0.99324057]
#  [0.99759247]
#  [0.00353506]]
#
# cost
#  0.004068867275025346
#
# iteration #  960
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00352711]
#  [0.99325549]
#  [0.99759783]
#  [0.00352711]]
#
# cost
#  0.0040597787859834285
#
# iteration #  961
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.0035192 ]
#  [0.99327035]
#  [0.99760317]
#  [0.0035192 ]]
#
# cost
#  0.004050728428435337
#
# iteration #  962
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00351131]
#  [0.99328515]
#  [0.99760849]
#  [0.00351131]]
#
# cost
#  0.00404171596978713
#
# iteration #  963
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00350346]
#  [0.99329988]
#  [0.99761378]
#  [0.00350346]]
#
# cost
#  0.004032741179299043
#
# iteration #  964
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00349565]
#  [0.99331456]
#  [0.99761906]
#  [0.00349565]]
#
# cost
#  0.004023803828066937
#
# iteration #  965
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00348786]
#  [0.99332917]
#  [0.99762431]
#  [0.00348786]]
#
# cost
#  0.004014903689004601
#
# iteration #  966
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00348011]
#  [0.99334373]
#  [0.99762954]
#  [0.00348011]]
#
# cost
#  0.00400604053682571
#
# iteration #  967
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00347239]
#  [0.99335822]
#  [0.99763475]
#  [0.00347239]]
#
# cost
#  0.003997214148026528
#
# iteration #  968
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00346471]
#  [0.99337266]
#  [0.99763993]
#  [0.00346471]]
#
# cost
#  0.003988424300868175
#
# iteration #  969
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00345705]
#  [0.99338704]
#  [0.9976451 ]
#  [0.00345705]]
#
# cost
#  0.003979670775359695
#
# iteration #  970
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00344943]
#  [0.99340136]
#  [0.99765024]
#  [0.00344943]]
#
# cost
#  0.003970953353241254
#
# iteration #  971
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00344183]
#  [0.99341562]
#  [0.99765536]
#  [0.00344183]]
#
# cost
#  0.003962271817966959
#
# iteration #  972
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00343427]
#  [0.99342982]
#  [0.99766046]
#  [0.00343427]]
#
# cost
#  0.003953625954688535
#
# iteration #  973
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00342674]
#  [0.99344397]
#  [0.99766554]
#  [0.00342674]]
#
# cost
#  0.0039450155502388775
#
# iteration #  974
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00341925]
#  [0.99345806]
#  [0.9976706 ]
#  [0.00341925]]
#
# cost
#  0.003936440393115954
#
# iteration #  975
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00341178]
#  [0.99347209]
#  [0.99767564]
#  [0.00341178]]
#
# cost
#  0.00392790027346639
#
# iteration #  976
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00340434]
#  [0.99348606]
#  [0.99768066]
#  [0.00340434]]
#
# cost
#  0.003919394983070241
#
# iteration #  977
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00339693]
#  [0.99349998]
#  [0.99768565]
#  [0.00339693]]
#
# cost
#  0.003910924315324861
#
# iteration #  978
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00338956]
#  [0.99351384]
#  [0.99769063]
#  [0.00338956]]
#
# cost
#  0.003902488065229597
#
# iteration #  979
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00338221]
#  [0.99352765]
#  [0.99769559]
#  [0.00338221]]
#
# cost
#  0.0038940860293702195
#
# iteration #  980
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00337489]
#  [0.9935414 ]
#  [0.99770052]
#  [0.00337489]]
#
# cost
#  0.0038857180059045943
#
# iteration #  981
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00336761]
#  [0.9935551 ]
#  [0.99770544]
#  [0.00336761]]
#
# cost
#  0.0038773837945466462
#
# iteration #  982
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00336035]
#  [0.99356874]
#  [0.99771033]
#  [0.00336035]]
#
# cost
#  0.003869083196552292
#
# iteration #  983
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00335312]
#  [0.99358233]
#  [0.99771521]
#  [0.00335312]]
#
# cost
#  0.0038608160147046494
#
# iteration #  984
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00334592]
#  [0.99359586]
#  [0.99772007]
#  [0.00334592]]
#
# cost
#  0.0038525820532993443
#
# iteration #  985
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00333875]
#  [0.99360934]
#  [0.9977249 ]
#  [0.00333875]]
#
# cost
#  0.003844381118130837
#
# iteration #  986
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00333161]
#  [0.99362277]
#  [0.99772972]
#  [0.00333161]]
#
# cost
#  0.003836213016477396
#
# iteration #  987
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.0033245 ]
#  [0.99363614]
#  [0.99773452]
#  [0.0033245 ]]
#
# cost
#  0.003828077557087823
#
# iteration #  988
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00331741]
#  [0.99364947]
#  [0.9977393 ]
#  [0.00331741]]
#
# cost
#  0.003819974550167429
#
# iteration #  989
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00331036]
#  [0.99366274]
#  [0.99774406]
#  [0.00331036]]
#
# cost
#  0.0038119038073641267
#
# iteration #  990
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00330333]
#  [0.99367595]
#  [0.9977488 ]
#  [0.00330333]]
#
# cost
#  0.0038038651417553857
#
# iteration #  991
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00329633]
#  [0.99368912]
#  [0.99775352]
#  [0.00329633]]
#
# cost
#  0.003795858367834437
#
# iteration #  992
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00328936]
#  [0.99370223]
#  [0.99775822]
#  [0.00328936]]
#
# cost
#  0.003787883301497263
#
# iteration #  993
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00328241]
#  [0.99371529]
#  [0.99776291]
#  [0.00328241]]
#
# cost
#  0.0037799397600295046
#
# iteration #  994
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00327549]
#  [0.9937283 ]
#  [0.99776757]
#  [0.00327549]]
#
# cost
#  0.003772027562093588
#
# iteration #  995
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00326861]
#  [0.99374127]
#  [0.99777222]
#  [0.00326861]]
#
# cost
#  0.003764146527715724
#
# iteration #  996
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00326174]
#  [0.99375418]
#  [0.99777685]
#  [0.00326174]]
#
# cost
#  0.003756296478273651
#
# iteration #  997
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00325491]
#  [0.99376704]
#  [0.99778146]
#  [0.00325491]]
#
# cost
#  0.003748477236483525
#
# iteration #  998
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.0032481 ]
#  [0.99377985]
#  [0.99778605]
#  [0.0032481 ]]
#
# cost
#  0.003740688626388282
#
# iteration #  999
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00324132]
#  [0.99379261]
#  [0.99779063]
#  [0.00324132]]
#
# cost
#  0.003732930473344916
#
# iteration #  1000
# Actual Output:
#  [[0]
#  [1]
#  [1]
#  [0]]
# Predicted Output:
#  [[0.00323456]
#  [0.99380532]
#  [0.99779518]
#  [0.00323456]]
#
# cost
#  0.003725202604012463

# %%
plt.scatter(range(epochs),losses)
plt.title("trining loss")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
